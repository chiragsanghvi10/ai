# %%
from __future__ import absolute_import, print_function, division

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 1.13.1

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
 (train_images, train_labels), (test_images, test_labels)= fashion_mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
img_data  = test_images[29]*255.0
from PIL import Image
img = Image.fromarray(img_data)
img.show()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
class_names[test_labels[1]]
# Out:
# 'Pullover'

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0
model.fit(train_images, train_labels, epochs = 15)
# Out:
# Epoch 1/15
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.4966 - acc: 0.8262
# Epoch 2/15
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.3784 - acc: 0.8634
# Epoch 3/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.3395 - acc: 0.8764
# Epoch 4/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.3152 - acc: 0.8836
# Epoch 5/15
# 60000/60000 [==============================] - 4s 58us/sample - loss: 0.2993 - acc: 0.8899
# Epoch 6/15
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.2851 - acc: 0.8940
# Epoch 7/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2742 - acc: 0.8984
# Epoch 8/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2603 - acc: 0.9026
# Epoch 9/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2534 - acc: 0.9057
# Epoch 10/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2438 - acc: 0.9087
# Epoch 11/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2351 - acc: 0.9117
# Epoch 12/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2266 - acc: 0.9153
# Epoch 13/15
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.2220 - acc: 0.9163
# Epoch 14/15
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.2145 - acc: 0.9195
# Epoch 15/15
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.2073 - acc: 0.9228

# %%
predictions = model.predict(test_images)

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 0s 25us/sample - loss: 0.3464 - acc: 0.8815
# [0.3464424235343933, 0.8815]

# %%
for i, pred in enumerate(predictions):
    print(str(i)+' -- Prediction ->'+str(class_names[np.argmax(predictions[i])])+' against actual ->'+str(class_names[test_labels[i]]))
# Out:
# 0 -- Prediction ->Ankle boot against actual ->Ankle boot
# 1 -- Prediction ->Pullover against actual ->Pullover
# 2 -- Prediction ->Trouser against actual ->Trouser
# 3 -- Prediction ->Trouser against actual ->Trouser
# 4 -- Prediction ->T-shirt/top against actual ->Shirt
# 5 -- Prediction ->Trouser against actual ->Trouser
# 6 -- Prediction ->Coat against actual ->Coat
# 7 -- Prediction ->Shirt against actual ->Shirt
# 8 -- Prediction ->Sandal against actual ->Sandal
# 9 -- Prediction ->Sneaker against actual ->Sneaker
# 10 -- Prediction ->Coat against actual ->Coat
# 11 -- Prediction ->Sandal against actual ->Sandal
# 12 -- Prediction ->Sneaker against actual ->Sneaker
# 13 -- Prediction ->Dress against actual ->Dress
# 14 -- Prediction ->Coat against actual ->Coat
# 15 -- Prediction ->Trouser against actual ->Trouser
# 16 -- Prediction ->Pullover against actual ->Pullover
# 17 -- Prediction ->Pullover against actual ->Coat
# 18 -- Prediction ->Bag against actual ->Bag
# 19 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 20 -- Prediction ->Pullover against actual ->Pullover
# 21 -- Prediction ->Sneaker against actual ->Sandal
# 22 -- Prediction ->Sneaker against actual ->Sneaker
# 23 -- Prediction ->Sandal against actual ->Ankle boot
# 24 -- Prediction ->Trouser against actual ->Trouser
# 25 -- Prediction ->Coat against actual ->Coat
# 26 -- Prediction ->Shirt against actual ->Shirt
# 27 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 28 -- Prediction ->Ankle boot against actual ->Ankle boot
# 29 -- Prediction ->Shirt against actual ->Dress
# 30 -- Prediction ->Bag against actual ->Bag
# 31 -- Prediction ->Bag against actual ->Bag
# 32 -- Prediction ->Dress against actual ->Dress
# 33 -- Prediction ->Dress against actual ->Dress
# 34 -- Prediction ->Bag against actual ->Bag
# 35 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 36 -- Prediction ->Sneaker against actual ->Sneaker
# 37 -- Prediction ->Sandal against actual ->Sandal
# 38 -- Prediction ->Sneaker against actual ->Sneaker
# 39 -- Prediction ->Ankle boot against actual ->Ankle boot
# 40 -- Prediction ->T-shirt/top against actual ->Shirt
# 41 -- Prediction ->Trouser against actual ->Trouser
# 42 -- Prediction ->Shirt against actual ->Dress
# 43 -- Prediction ->Sneaker against actual ->Sneaker
# 44 -- Prediction ->Shirt against actual ->Shirt
# 45 -- Prediction ->Sneaker against actual ->Sneaker
# 46 -- Prediction ->Pullover against actual ->Pullover
# 47 -- Prediction ->Trouser against actual ->Trouser
# 48 -- Prediction ->Pullover against actual ->Pullover
# 49 -- Prediction ->Shirt against actual ->Pullover
# 50 -- Prediction ->Coat against actual ->Coat
# 51 -- Prediction ->Coat against actual ->Coat
# 52 -- Prediction ->Sandal against actual ->Sandal
# 53 -- Prediction ->Bag against actual ->Bag
# 54 -- Prediction ->Pullover against actual ->Pullover
# 55 -- Prediction ->Pullover against actual ->Pullover
# 56 -- Prediction ->Bag against actual ->Bag
# 57 -- Prediction ->Shirt against actual ->Coat
# 58 -- Prediction ->Bag against actual ->Bag
# 59 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 60 -- Prediction ->Sneaker against actual ->Sneaker
# 61 -- Prediction ->Sneaker against actual ->Sneaker
# 62 -- Prediction ->Bag against actual ->Bag
# 63 -- Prediction ->Sandal against actual ->Sandal
# 64 -- Prediction ->Trouser against actual ->Trouser
# 65 -- Prediction ->Trouser against actual ->Trouser
# 66 -- Prediction ->Dress against actual ->Pullover
# 67 -- Prediction ->Dress against actual ->Dress
# 68 -- Prediction ->Sneaker against actual ->Ankle boot
# 69 -- Prediction ->Bag against actual ->Bag
# 70 -- Prediction ->Sneaker against actual ->Sneaker
# 71 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 72 -- Prediction ->Pullover against actual ->Pullover
# 73 -- Prediction ->Shirt against actual ->Shirt
# 74 -- Prediction ->Coat against actual ->Pullover
# 75 -- Prediction ->Dress against actual ->Dress
# 76 -- Prediction ->Trouser against actual ->Trouser
# 77 -- Prediction ->Pullover against actual ->Pullover
# 78 -- Prediction ->Bag against actual ->Bag
# 79 -- Prediction ->Coat against actual ->Coat
# 80 -- Prediction ->Trouser against actual ->Trouser
# 81 -- Prediction ->Bag against actual ->Bag
# 82 -- Prediction ->Sandal against actual ->Sandal
# 83 -- Prediction ->Ankle boot against actual ->Ankle boot
# 84 -- Prediction ->Sandal against actual ->Sandal
# 85 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 86 -- Prediction ->Dress against actual ->Dress
# 87 -- Prediction ->Pullover against actual ->Pullover
# 88 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 89 -- Prediction ->T-shirt/top against actual ->Shirt
# 90 -- Prediction ->Sandal against actual ->Sandal
# 91 -- Prediction ->Dress against actual ->Dress
# 92 -- Prediction ->Shirt against actual ->Shirt
# 93 -- Prediction ->Sneaker against actual ->Sneaker
# 94 -- Prediction ->Trouser against actual ->Trouser
# 95 -- Prediction ->Bag against actual ->Bag
# 96 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 97 -- Prediction ->Trouser against actual ->Trouser
# 98 -- Prediction ->Coat against actual ->Coat
# 99 -- Prediction ->Pullover against actual ->Pullover
# 100 -- Prediction ->Dress against actual ->Dress
# 101 -- Prediction ->Shirt against actual ->Shirt
# 102 -- Prediction ->Sneaker against actual ->Sneaker
# 103 -- Prediction ->Shirt against actual ->Pullover
# 104 -- Prediction ->Sneaker against actual ->Sneaker
# 105 -- Prediction ->Bag against actual ->Bag
# 106 -- Prediction ->Sandal against actual ->Sandal
# 107 -- Prediction ->Ankle boot against actual ->Ankle boot
# 108 -- Prediction ->Ankle boot against actual ->Ankle boot
# 109 -- Prediction ->Coat against actual ->Coat
# 110 -- Prediction ->Pullover against actual ->Pullover
# 111 -- Prediction ->Sandal against actual ->Sandal
# 112 -- Prediction ->Sneaker against actual ->Sneaker
# 113 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 114 -- Prediction ->Sandal against actual ->Sandal
# 115 -- Prediction ->Pullover against actual ->Pullover
# 116 -- Prediction ->Bag against actual ->Bag
# 117 -- Prediction ->Shirt against actual ->Shirt
# 118 -- Prediction ->Sneaker against actual ->Sneaker
# 119 -- Prediction ->Bag against actual ->Bag
# 120 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 121 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 122 -- Prediction ->Ankle boot against actual ->Ankle boot
# 123 -- Prediction ->Ankle boot against actual ->Ankle boot
# 124 -- Prediction ->Dress against actual ->Dress
# 125 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 126 -- Prediction ->Bag against actual ->Bag
# 127 -- Prediction ->Coat against actual ->Coat
# 128 -- Prediction ->Trouser against actual ->Trouser
# 129 -- Prediction ->Sandal against actual ->Sandal
# 130 -- Prediction ->Coat against actual ->Coat
# 131 -- Prediction ->Trouser against actual ->Trouser
# 132 -- Prediction ->Ankle boot against actual ->Ankle boot
# 133 -- Prediction ->Trouser against actual ->Trouser
# 134 -- Prediction ->Bag against actual ->Bag
# 135 -- Prediction ->Shirt against actual ->Shirt
# 136 -- Prediction ->Shirt against actual ->Pullover
# 137 -- Prediction ->Trouser against actual ->Trouser
# 138 -- Prediction ->Pullover against actual ->Pullover
# 139 -- Prediction ->Sandal against actual ->Sandal
# 140 -- Prediction ->Trouser against actual ->Trouser
# 141 -- Prediction ->Shirt against actual ->T-shirt/top
# 142 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 143 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 144 -- Prediction ->Trouser against actual ->Trouser
# 145 -- Prediction ->Shirt against actual ->Shirt
# 146 -- Prediction ->Trouser against actual ->Trouser
# 147 -- Prediction ->Dress against actual ->Shirt
# 148 -- Prediction ->Pullover against actual ->Pullover
# 149 -- Prediction ->Pullover against actual ->Pullover
# 150 -- Prediction ->Dress against actual ->Coat
# 151 -- Prediction ->Bag against actual ->Coat
# 152 -- Prediction ->Trouser against actual ->Trouser
# 153 -- Prediction ->Dress against actual ->Coat
# 154 -- Prediction ->Sandal against actual ->Sandal
# 155 -- Prediction ->Shirt against actual ->T-shirt/top
# 156 -- Prediction ->Coat against actual ->Coat
# 157 -- Prediction ->Sneaker against actual ->Sneaker
# 158 -- Prediction ->Ankle boot against actual ->Ankle boot
# 159 -- Prediction ->Dress against actual ->Dress
# 160 -- Prediction ->Sneaker against actual ->Sneaker
# 161 -- Prediction ->Pullover against actual ->Pullover
# 162 -- Prediction ->Dress against actual ->Dress
# 163 -- Prediction ->Ankle boot against actual ->Ankle boot
# 164 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 165 -- Prediction ->Ankle boot against actual ->Ankle boot
# 166 -- Prediction ->Coat against actual ->Coat
# 167 -- Prediction ->Sneaker against actual ->Sneaker
# 168 -- Prediction ->Coat against actual ->Coat
# 169 -- Prediction ->Pullover against actual ->Pullover
# 170 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 171 -- Prediction ->Sandal against actual ->Sandal
# 172 -- Prediction ->Shirt against actual ->Pullover
# 173 -- Prediction ->Trouser against actual ->Trouser
# 174 -- Prediction ->Pullover against actual ->Pullover
# 175 -- Prediction ->Trouser against actual ->Trouser
# 176 -- Prediction ->Dress against actual ->Dress
# 177 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 178 -- Prediction ->Ankle boot against actual ->Ankle boot
# 179 -- Prediction ->Trouser against actual ->Trouser
# 180 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 181 -- Prediction ->Ankle boot against actual ->Ankle boot
# 182 -- Prediction ->Dress against actual ->Dress
# 183 -- Prediction ->Shirt against actual ->Shirt
# 184 -- Prediction ->Sneaker against actual ->Sneaker
# 185 -- Prediction ->Ankle boot against actual ->Ankle boot
# 186 -- Prediction ->Ankle boot against actual ->Ankle boot
# 187 -- Prediction ->Coat against actual ->Coat
# 188 -- Prediction ->Coat against actual ->Coat
# 189 -- Prediction ->Sneaker against actual ->Sneaker
# 190 -- Prediction ->Trouser against actual ->Trouser
# 191 -- Prediction ->Pullover against actual ->Pullover
# 192 -- Prediction ->Dress against actual ->Trouser
# 193 -- Prediction ->Shirt against actual ->Shirt
# 194 -- Prediction ->Dress against actual ->Dress
# 195 -- Prediction ->Pullover against actual ->Pullover
# 196 -- Prediction ->Bag against actual ->Bag
# 197 -- Prediction ->Dress against actual ->Dress
# 198 -- Prediction ->Shirt against actual ->Shirt
# 199 -- Prediction ->Trouser against actual ->Trouser
# 200 -- Prediction ->Trouser against actual ->Trouser
# 201 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 202 -- Prediction ->Pullover against actual ->Pullover
# 203 -- Prediction ->Ankle boot against actual ->Ankle boot
# 204 -- Prediction ->Pullover against actual ->Pullover
# 205 -- Prediction ->Coat against actual ->Coat
# 206 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 207 -- Prediction ->Sneaker against actual ->Sneaker
# 208 -- Prediction ->Ankle boot against actual ->Ankle boot
# 209 -- Prediction ->Bag against actual ->Bag
# 210 -- Prediction ->Coat against actual ->Coat
# 211 -- Prediction ->Trouser against actual ->Trouser
# 212 -- Prediction ->Bag against actual ->Bag
# 213 -- Prediction ->Coat against actual ->Coat
# 214 -- Prediction ->Trouser against actual ->Trouser
# 215 -- Prediction ->Dress against actual ->Dress
# 216 -- Prediction ->Trouser against actual ->Trouser
# 217 -- Prediction ->Shirt against actual ->Shirt
# 218 -- Prediction ->Sneaker against actual ->Sneaker
# 219 -- Prediction ->Pullover against actual ->Pullover
# 220 -- Prediction ->Bag against actual ->Bag
# 221 -- Prediction ->Bag against actual ->Sandal
# 222 -- Prediction ->Dress against actual ->Pullover
# 223 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 224 -- Prediction ->Sneaker against actual ->Sneaker
# 225 -- Prediction ->Sneaker against actual ->Sneaker
# 226 -- Prediction ->Shirt against actual ->Shirt
# 227 -- Prediction ->Shirt against actual ->Pullover
# 228 -- Prediction ->Sneaker against actual ->Sneaker
# 229 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 230 -- Prediction ->Sneaker against actual ->Sneaker
# 231 -- Prediction ->Bag against actual ->Bag
# 232 -- Prediction ->Ankle boot against actual ->Ankle boot
# 233 -- Prediction ->Pullover against actual ->Pullover
# 234 -- Prediction ->Ankle boot against actual ->Ankle boot
# 235 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 236 -- Prediction ->Sandal against actual ->Sandal
# 237 -- Prediction ->Trouser against actual ->Trouser
# 238 -- Prediction ->Coat against actual ->Coat
# 239 -- Prediction ->Pullover against actual ->Coat
# 240 -- Prediction ->Sandal against actual ->Sandal
# 241 -- Prediction ->Coat against actual ->Shirt
# 242 -- Prediction ->Ankle boot against actual ->Ankle boot
# 243 -- Prediction ->Pullover against actual ->Pullover
# 244 -- Prediction ->Pullover against actual ->Shirt
# 245 -- Prediction ->Bag against actual ->Bag
# 246 -- Prediction ->Shirt against actual ->Shirt
# 247 -- Prediction ->Shirt against actual ->Coat
# 248 -- Prediction ->Pullover against actual ->Pullover
# 249 -- Prediction ->Pullover against actual ->Pullover
# 250 -- Prediction ->Ankle boot against actual ->Ankle boot
# 251 -- Prediction ->Sneaker against actual ->Sneaker
# 252 -- Prediction ->T-shirt/top against actual ->Shirt
# 253 -- Prediction ->Sandal against actual ->Sandal
# 254 -- Prediction ->Sandal against actual ->Sandal
# 255 -- Prediction ->Coat against actual ->Pullover
# 256 -- Prediction ->Bag against actual ->Bag
# 257 -- Prediction ->Sandal against actual ->Sandal
# 258 -- Prediction ->Pullover against actual ->Pullover
# 259 -- Prediction ->Dress against actual ->Dress
# 260 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 261 -- Prediction ->Coat against actual ->Coat
# 262 -- Prediction ->Bag against actual ->Bag
# 263 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 264 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 265 -- Prediction ->Shirt against actual ->Shirt
# 266 -- Prediction ->Dress against actual ->Dress
# 267 -- Prediction ->Bag against actual ->Bag
# 268 -- Prediction ->Ankle boot against actual ->Ankle boot
# 269 -- Prediction ->Shirt against actual ->Shirt
# 270 -- Prediction ->Trouser against actual ->Trouser
# 271 -- Prediction ->Dress against actual ->Dress
# 272 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 273 -- Prediction ->Pullover against actual ->Pullover
# 274 -- Prediction ->Dress against actual ->Dress
# 275 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 276 -- Prediction ->Bag against actual ->Bag
# 277 -- Prediction ->Dress against actual ->Dress
# 278 -- Prediction ->Sneaker against actual ->Sneaker
# 279 -- Prediction ->Coat against actual ->Coat
# 280 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 281 -- Prediction ->Trouser against actual ->Trouser
# 282 -- Prediction ->Shirt against actual ->Shirt
# 283 -- Prediction ->Dress against actual ->Dress
# 284 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 285 -- Prediction ->Shirt against actual ->Shirt
# 286 -- Prediction ->Shirt against actual ->Shirt
# 287 -- Prediction ->Sneaker against actual ->Sneaker
# 288 -- Prediction ->Sandal against actual ->Sandal
# 289 -- Prediction ->Coat against actual ->Coat
# 290 -- Prediction ->Sandal against actual ->Sandal
# 291 -- Prediction ->Ankle boot against actual ->Ankle boot
# 292 -- Prediction ->Sandal against actual ->Sandal
# 293 -- Prediction ->Shirt against actual ->Shirt
# 294 -- Prediction ->Sandal against actual ->Sandal
# 295 -- Prediction ->Sandal against actual ->Sandal
# 296 -- Prediction ->Trouser against actual ->Trouser
# 297 -- Prediction ->Ankle boot against actual ->Ankle boot
# 298 -- Prediction ->Bag against actual ->Bag
# 299 -- Prediction ->Bag against actual ->Bag
# 300 -- Prediction ->Dress against actual ->Dress
# 301 -- Prediction ->Dress against actual ->Dress
# 302 -- Prediction ->Shirt against actual ->Shirt
# 303 -- Prediction ->Bag against actual ->Bag
# 304 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 305 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 306 -- Prediction ->Pullover against actual ->Pullover
# 307 -- Prediction ->Ankle boot against actual ->Ankle boot
# 308 -- Prediction ->Sneaker against actual ->Sneaker
# 309 -- Prediction ->Ankle boot against actual ->Sneaker
# 310 -- Prediction ->Trouser against actual ->Trouser
# 311 -- Prediction ->Dress against actual ->Dress
# 312 -- Prediction ->Shirt against actual ->Shirt
# 313 -- Prediction ->Shirt against actual ->Coat
# 314 -- Prediction ->Shirt against actual ->Pullover
# 315 -- Prediction ->Coat against actual ->Coat
# 316 -- Prediction ->Sneaker against actual ->Ankle boot
# 317 -- Prediction ->Trouser against actual ->Trouser
# 318 -- Prediction ->Shirt against actual ->Shirt
# 319 -- Prediction ->Coat against actual ->Coat
# 320 -- Prediction ->Bag against actual ->Bag
# 321 -- Prediction ->Pullover against actual ->Pullover
# 322 -- Prediction ->Shirt against actual ->Shirt
# 323 -- Prediction ->Sandal against actual ->Sandal
# 324 -- Prediction ->Shirt against actual ->Coat
# 325 -- Prediction ->Pullover against actual ->Shirt
# 326 -- Prediction ->Sneaker against actual ->Sneaker
# 327 -- Prediction ->Sneaker against actual ->Sneaker
# 328 -- Prediction ->Sneaker against actual ->Sneaker
# 329 -- Prediction ->Dress against actual ->Dress
# 330 -- Prediction ->Dress against actual ->Dress
# 331 -- Prediction ->Sneaker against actual ->Sneaker
# 332 -- Prediction ->Shirt against actual ->T-shirt/top
# 333 -- Prediction ->Sneaker against actual ->Sneaker
# 334 -- Prediction ->Trouser against actual ->Trouser
# 335 -- Prediction ->Dress against actual ->Dress
# 336 -- Prediction ->Sneaker against actual ->Sneaker
# 337 -- Prediction ->Pullover against actual ->Pullover
# 338 -- Prediction ->Pullover against actual ->Pullover
# 339 -- Prediction ->Dress against actual ->Dress
# 340 -- Prediction ->Coat against actual ->Coat
# 341 -- Prediction ->Shirt against actual ->T-shirt/top
# 342 -- Prediction ->Dress against actual ->Dress
# 343 -- Prediction ->Trouser against actual ->Trouser
# 344 -- Prediction ->Shirt against actual ->Shirt
# 345 -- Prediction ->Trouser against actual ->Trouser
# 346 -- Prediction ->Ankle boot against actual ->Ankle boot
# 347 -- Prediction ->Coat against actual ->Coat
# 348 -- Prediction ->Ankle boot against actual ->Ankle boot
# 349 -- Prediction ->Ankle boot against actual ->Ankle boot
# 350 -- Prediction ->Trouser against actual ->Trouser
# 351 -- Prediction ->Sneaker against actual ->Sneaker
# 352 -- Prediction ->T-shirt/top against actual ->Bag
# 353 -- Prediction ->Dress against actual ->Dress
# 354 -- Prediction ->Shirt against actual ->Shirt
# 355 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 356 -- Prediction ->Pullover against actual ->Pullover
# 357 -- Prediction ->Coat against actual ->Coat
# 358 -- Prediction ->Bag against actual ->Bag
# 359 -- Prediction ->Shirt against actual ->T-shirt/top
# 360 -- Prediction ->Trouser against actual ->Trouser
# 361 -- Prediction ->Shirt against actual ->Pullover
# 362 -- Prediction ->Pullover against actual ->Pullover
# 363 -- Prediction ->Coat against actual ->Coat
# 364 -- Prediction ->Coat against actual ->Coat
# 365 -- Prediction ->Sneaker against actual ->Sneaker
# 366 -- Prediction ->Dress against actual ->Dress
# 367 -- Prediction ->Pullover against actual ->Pullover
# 368 -- Prediction ->Shirt against actual ->Pullover
# 369 -- Prediction ->Sandal against actual ->Sandal
# 370 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 371 -- Prediction ->Sneaker against actual ->Sneaker
# 372 -- Prediction ->Ankle boot against actual ->Ankle boot
# 373 -- Prediction ->Coat against actual ->Coat
# 374 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 375 -- Prediction ->Ankle boot against actual ->Ankle boot
# 376 -- Prediction ->Dress against actual ->Dress
# 377 -- Prediction ->Ankle boot against actual ->Ankle boot
# 378 -- Prediction ->Dress against actual ->Coat
# 379 -- Prediction ->Dress against actual ->Pullover
# 380 -- Prediction ->Sandal against actual ->Sandal
# 381 -- Prediction ->Shirt against actual ->T-shirt/top
# 382 -- Prediction ->T-shirt/top against actual ->Pullover
# 383 -- Prediction ->Dress against actual ->Dress
# 384 -- Prediction ->Sandal against actual ->Sandal
# 385 -- Prediction ->Bag against actual ->Bag
# 386 -- Prediction ->Trouser against actual ->Trouser
# 387 -- Prediction ->Shirt against actual ->Shirt
# 388 -- Prediction ->Pullover against actual ->Pullover
# 389 -- Prediction ->Shirt against actual ->Shirt
# 390 -- Prediction ->Shirt against actual ->Shirt
# 391 -- Prediction ->Coat against actual ->Coat
# 392 -- Prediction ->Ankle boot against actual ->Ankle boot
# 393 -- Prediction ->Sandal against actual ->Sandal
# 394 -- Prediction ->Coat against actual ->Pullover
# 395 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 396 -- Prediction ->Shirt against actual ->Coat
# 397 -- Prediction ->Shirt against actual ->Shirt
# 398 -- Prediction ->Trouser against actual ->Trouser
# 399 -- Prediction ->Pullover against actual ->Pullover
# 400 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 401 -- Prediction ->Ankle boot against actual ->Ankle boot
# 402 -- Prediction ->Sneaker against actual ->Sneaker
# 403 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 404 -- Prediction ->Dress against actual ->Coat
# 405 -- Prediction ->Coat against actual ->Coat
# 406 -- Prediction ->Dress against actual ->Shirt
# 407 -- Prediction ->T-shirt/top against actual ->Shirt
# 408 -- Prediction ->Pullover against actual ->Pullover
# 409 -- Prediction ->Trouser against actual ->Trouser
# 410 -- Prediction ->Shirt against actual ->T-shirt/top
# 411 -- Prediction ->Shirt against actual ->Shirt
# 412 -- Prediction ->Sneaker against actual ->Sneaker
# 413 -- Prediction ->T-shirt/top against actual ->Pullover
# 414 -- Prediction ->Ankle boot against actual ->Ankle boot
# 415 -- Prediction ->Coat against actual ->Coat
# 416 -- Prediction ->Pullover against actual ->Pullover
# 417 -- Prediction ->Trouser against actual ->Trouser
# 418 -- Prediction ->Sandal against actual ->Sandal
# 419 -- Prediction ->Coat against actual ->Coat
# 420 -- Prediction ->Sandal against actual ->Sandal
# 421 -- Prediction ->Dress against actual ->Dress
# 422 -- Prediction ->Bag against actual ->Bag
# 423 -- Prediction ->Sandal against actual ->Sandal
# 424 -- Prediction ->Bag against actual ->Bag
# 425 -- Prediction ->Coat against actual ->Coat
# 426 -- Prediction ->Coat against actual ->Coat
# 427 -- Prediction ->Bag against actual ->Bag
# 428 -- Prediction ->Ankle boot against actual ->Ankle boot
# 429 -- Prediction ->Bag against actual ->Bag
# 430 -- Prediction ->Shirt against actual ->Shirt
# 431 -- Prediction ->Shirt against actual ->Pullover
# 432 -- Prediction ->Coat against actual ->Coat
# 433 -- Prediction ->Coat against actual ->Coat
# 434 -- Prediction ->Pullover against actual ->Pullover
# 435 -- Prediction ->Coat against actual ->Coat
# 436 -- Prediction ->Trouser against actual ->Trouser
# 437 -- Prediction ->Shirt against actual ->Shirt
# 438 -- Prediction ->Trouser against actual ->Trouser
# 439 -- Prediction ->Dress against actual ->Dress
# 440 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 441 -- Prediction ->Sneaker against actual ->Ankle boot
# 442 -- Prediction ->Bag against actual ->Bag
# 443 -- Prediction ->Bag against actual ->Bag
# 444 -- Prediction ->Coat against actual ->Shirt
# 445 -- Prediction ->Sandal against actual ->Sandal
# 446 -- Prediction ->Dress against actual ->Dress
# 447 -- Prediction ->Trouser against actual ->Trouser
# 448 -- Prediction ->Ankle boot against actual ->Ankle boot
# 449 -- Prediction ->Sandal against actual ->Sandal
# 450 -- Prediction ->Dress against actual ->Dress
# 451 -- Prediction ->Dress against actual ->Dress
# 452 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 453 -- Prediction ->Trouser against actual ->Trouser
# 454 -- Prediction ->Pullover against actual ->T-shirt/top
# 455 -- Prediction ->Pullover against actual ->Pullover
# 456 -- Prediction ->Ankle boot against actual ->Ankle boot
# 457 -- Prediction ->Coat against actual ->Pullover
# 458 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 459 -- Prediction ->Shirt against actual ->Shirt
# 460 -- Prediction ->T-shirt/top against actual ->Dress
# 461 -- Prediction ->Coat against actual ->Coat
# 462 -- Prediction ->Pullover against actual ->Pullover
# 463 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 464 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 465 -- Prediction ->Dress against actual ->Dress
# 466 -- Prediction ->Dress against actual ->Dress
# 467 -- Prediction ->Bag against actual ->Bag
# 468 -- Prediction ->Pullover against actual ->Pullover
# 469 -- Prediction ->Bag against actual ->Bag
# 470 -- Prediction ->Ankle boot against actual ->Ankle boot
# 471 -- Prediction ->Coat against actual ->Coat
# 472 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 473 -- Prediction ->Sneaker against actual ->Sneaker
# 474 -- Prediction ->Pullover against actual ->Shirt
# 475 -- Prediction ->Coat against actual ->Coat
# 476 -- Prediction ->Coat against actual ->Coat
# 477 -- Prediction ->Ankle boot against actual ->Ankle boot
# 478 -- Prediction ->Pullover against actual ->Pullover
# 479 -- Prediction ->Ankle boot against actual ->Ankle boot
# 480 -- Prediction ->Sneaker against actual ->Sandal
# 481 -- Prediction ->Ankle boot against actual ->Ankle boot
# 482 -- Prediction ->Dress against actual ->Dress
# 483 -- Prediction ->Sneaker against actual ->Sneaker
# 484 -- Prediction ->Sandal against actual ->Sandal
# 485 -- Prediction ->Sneaker against actual ->Sneaker
# 486 -- Prediction ->Bag against actual ->Bag
# 487 -- Prediction ->Trouser against actual ->Trouser
# 488 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 489 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 490 -- Prediction ->Dress against actual ->Dress
# 491 -- Prediction ->Shirt against actual ->Coat
# 492 -- Prediction ->Bag against actual ->Bag
# 493 -- Prediction ->Ankle boot against actual ->Ankle boot
# 494 -- Prediction ->Sneaker against actual ->Sneaker
# 495 -- Prediction ->Ankle boot against actual ->Ankle boot
# 496 -- Prediction ->Trouser against actual ->Trouser
# 497 -- Prediction ->Pullover against actual ->Pullover
# 498 -- Prediction ->Sneaker against actual ->Sneaker
# 499 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 500 -- Prediction ->Pullover against actual ->Pullover
# 501 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 502 -- Prediction ->Sandal against actual ->Sandal
# 503 -- Prediction ->Sneaker against actual ->Sneaker
# 504 -- Prediction ->Trouser against actual ->Trouser
# 505 -- Prediction ->Bag against actual ->Bag
# 506 -- Prediction ->Pullover against actual ->Pullover
# 507 -- Prediction ->Pullover against actual ->Pullover
# 508 -- Prediction ->Pullover against actual ->Pullover
# 509 -- Prediction ->Pullover against actual ->Pullover
# 510 -- Prediction ->Coat against actual ->Coat
# 511 -- Prediction ->Coat against actual ->Pullover
# 512 -- Prediction ->Shirt against actual ->Shirt
# 513 -- Prediction ->Trouser against actual ->Trouser
# 514 -- Prediction ->Ankle boot against actual ->Ankle boot
# 515 -- Prediction ->Bag against actual ->Bag
# 516 -- Prediction ->Sandal against actual ->Sandal
# 517 -- Prediction ->Trouser against actual ->Trouser
# 518 -- Prediction ->Ankle boot against actual ->Ankle boot
# 519 -- Prediction ->Trouser against actual ->Trouser
# 520 -- Prediction ->Pullover against actual ->Pullover
# 521 -- Prediction ->Bag against actual ->Bag
# 522 -- Prediction ->Dress against actual ->Dress
# 523 -- Prediction ->Bag against actual ->Bag
# 524 -- Prediction ->Ankle boot against actual ->Ankle boot
# 525 -- Prediction ->Pullover against actual ->Pullover
# 526 -- Prediction ->Coat against actual ->Coat
# 527 -- Prediction ->Coat against actual ->Pullover
# 528 -- Prediction ->Bag against actual ->Bag
# 529 -- Prediction ->T-shirt/top against actual ->Bag
# 530 -- Prediction ->Pullover against actual ->Pullover
# 531 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 532 -- Prediction ->Sandal against actual ->Sandal
# 533 -- Prediction ->Bag against actual ->Bag
# 534 -- Prediction ->Bag against actual ->Bag
# 535 -- Prediction ->Sandal against actual ->Sandal
# 536 -- Prediction ->T-shirt/top against actual ->Dress
# 537 -- Prediction ->Ankle boot against actual ->Ankle boot
# 538 -- Prediction ->Coat against actual ->Coat
# 539 -- Prediction ->Dress against actual ->Dress
# 540 -- Prediction ->Coat against actual ->Coat
# 541 -- Prediction ->Coat against actual ->Coat
# 542 -- Prediction ->Sandal against actual ->Sandal
# 543 -- Prediction ->Trouser against actual ->Trouser
# 544 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 545 -- Prediction ->Trouser against actual ->Trouser
# 546 -- Prediction ->Pullover against actual ->Pullover
# 547 -- Prediction ->Shirt against actual ->T-shirt/top
# 548 -- Prediction ->Coat against actual ->Shirt
# 549 -- Prediction ->Ankle boot against actual ->Ankle boot
# 550 -- Prediction ->Shirt against actual ->Shirt
# 551 -- Prediction ->Trouser against actual ->Trouser
# 552 -- Prediction ->Sandal against actual ->Sandal
# 553 -- Prediction ->Trouser against actual ->Trouser
# 554 -- Prediction ->Trouser against actual ->Trouser
# 555 -- Prediction ->Trouser against actual ->Trouser
# 556 -- Prediction ->Ankle boot against actual ->Ankle boot
# 557 -- Prediction ->Dress against actual ->Dress
# 558 -- Prediction ->Coat against actual ->Coat
# 559 -- Prediction ->Sandal against actual ->Sandal
# 560 -- Prediction ->Dress against actual ->Dress
# 561 -- Prediction ->Shirt against actual ->Shirt
# 562 -- Prediction ->Shirt against actual ->Shirt
# 563 -- Prediction ->T-shirt/top against actual ->Shirt
# 564 -- Prediction ->Coat against actual ->Coat
# 565 -- Prediction ->T-shirt/top against actual ->Shirt
# 566 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 567 -- Prediction ->Sandal against actual ->Sandal
# 568 -- Prediction ->Bag against actual ->Bag
# 569 -- Prediction ->Dress against actual ->Dress
# 570 -- Prediction ->Dress against actual ->Dress
# 571 -- Prediction ->Coat against actual ->Coat
# 572 -- Prediction ->Shirt against actual ->Shirt
# 573 -- Prediction ->Sneaker against actual ->Sneaker
# 574 -- Prediction ->Sneaker against actual ->Sneaker
# 575 -- Prediction ->Bag against actual ->Bag
# 576 -- Prediction ->Ankle boot against actual ->Ankle boot
# 577 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 578 -- Prediction ->Dress against actual ->Dress
# 579 -- Prediction ->Bag against actual ->Bag
# 580 -- Prediction ->Sneaker against actual ->Sneaker
# 581 -- Prediction ->Shirt against actual ->Shirt
# 582 -- Prediction ->Sneaker against actual ->Sneaker
# 583 -- Prediction ->Ankle boot against actual ->Ankle boot
# 584 -- Prediction ->Dress against actual ->Dress
# 585 -- Prediction ->Coat against actual ->Coat
# 586 -- Prediction ->Shirt against actual ->Shirt
# 587 -- Prediction ->Shirt against actual ->Shirt
# 588 -- Prediction ->Sandal against actual ->Sandal
# 589 -- Prediction ->Bag against actual ->T-shirt/top
# 590 -- Prediction ->Trouser against actual ->Trouser
# 591 -- Prediction ->Trouser against actual ->Trouser
# 592 -- Prediction ->Sandal against actual ->Sandal
# 593 -- Prediction ->Ankle boot against actual ->Ankle boot
# 594 -- Prediction ->Dress against actual ->Coat
# 595 -- Prediction ->Pullover against actual ->Shirt
# 596 -- Prediction ->Sandal against actual ->Sandal
# 597 -- Prediction ->Sneaker against actual ->Sneaker
# 598 -- Prediction ->Bag against actual ->Bag
# 599 -- Prediction ->Trouser against actual ->Trouser
# 600 -- Prediction ->Pullover against actual ->Pullover
# 601 -- Prediction ->Ankle boot against actual ->Ankle boot
# 602 -- Prediction ->Sneaker against actual ->Sneaker
# 603 -- Prediction ->Sneaker against actual ->Sneaker
# 604 -- Prediction ->Trouser against actual ->Trouser
# 605 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 606 -- Prediction ->Ankle boot against actual ->Ankle boot
# 607 -- Prediction ->Dress against actual ->Dress
# 608 -- Prediction ->Pullover against actual ->Pullover
# 609 -- Prediction ->Ankle boot against actual ->Ankle boot
# 610 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 611 -- Prediction ->Sneaker against actual ->Sneaker
# 612 -- Prediction ->Shirt against actual ->Shirt
# 613 -- Prediction ->Bag against actual ->Bag
# 614 -- Prediction ->Pullover against actual ->Pullover
# 615 -- Prediction ->Sneaker against actual ->Sneaker
# 616 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 617 -- Prediction ->Pullover against actual ->Pullover
# 618 -- Prediction ->Dress against actual ->Dress
# 619 -- Prediction ->Bag against actual ->Bag
# 620 -- Prediction ->Pullover against actual ->Pullover
# 621 -- Prediction ->Pullover against actual ->Pullover
# 622 -- Prediction ->Shirt against actual ->Shirt
# 623 -- Prediction ->Sneaker against actual ->Ankle boot
# 624 -- Prediction ->Dress against actual ->Dress
# 625 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 626 -- Prediction ->Sneaker against actual ->Sneaker
# 627 -- Prediction ->Bag against actual ->Bag
# 628 -- Prediction ->Shirt against actual ->Shirt
# 629 -- Prediction ->Pullover against actual ->Pullover
# 630 -- Prediction ->Ankle boot against actual ->Ankle boot
# 631 -- Prediction ->Coat against actual ->Coat
# 632 -- Prediction ->Pullover against actual ->Pullover
# 633 -- Prediction ->Shirt against actual ->Shirt
# 634 -- Prediction ->Shirt against actual ->Shirt
# 635 -- Prediction ->T-shirt/top against actual ->Bag
# 636 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 637 -- Prediction ->Shirt against actual ->Coat
# 638 -- Prediction ->Coat against actual ->Coat
# 639 -- Prediction ->Coat against actual ->Coat
# 640 -- Prediction ->Sneaker against actual ->Sneaker
# 641 -- Prediction ->Sandal against actual ->Sandal
# 642 -- Prediction ->Bag against actual ->Bag
# 643 -- Prediction ->Coat against actual ->Coat
# 644 -- Prediction ->Ankle boot against actual ->Ankle boot
# 645 -- Prediction ->Trouser against actual ->Trouser
# 646 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 647 -- Prediction ->Sandal against actual ->Sandal
# 648 -- Prediction ->Coat against actual ->Coat
# 649 -- Prediction ->Coat against actual ->Coat
# 650 -- Prediction ->Coat against actual ->Coat
# 651 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 652 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 653 -- Prediction ->Coat against actual ->Coat
# 654 -- Prediction ->Sandal against actual ->Sandal
# 655 -- Prediction ->Shirt against actual ->Shirt
# 656 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 657 -- Prediction ->Coat against actual ->Coat
# 658 -- Prediction ->Sandal against actual ->Sandal
# 659 -- Prediction ->Coat against actual ->Coat
# 660 -- Prediction ->Trouser against actual ->Trouser
# 661 -- Prediction ->Dress against actual ->Dress
# 662 -- Prediction ->Trouser against actual ->Trouser
# 663 -- Prediction ->Dress against actual ->Trouser
# 664 -- Prediction ->Shirt against actual ->Shirt
# 665 -- Prediction ->Coat against actual ->Coat
# 666 -- Prediction ->Dress against actual ->Dress
# 667 -- Prediction ->Bag against actual ->Bag
# 668 -- Prediction ->Pullover against actual ->Pullover
# 669 -- Prediction ->T-shirt/top against actual ->Bag
# 670 -- Prediction ->Shirt against actual ->Pullover
# 671 -- Prediction ->Sneaker against actual ->Sneaker
# 672 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 673 -- Prediction ->Coat against actual ->Coat
# 674 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 675 -- Prediction ->Bag against actual ->Bag
# 676 -- Prediction ->Sandal against actual ->Sandal
# 677 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 678 -- Prediction ->Bag against actual ->Bag
# 679 -- Prediction ->Pullover against actual ->Pullover
# 680 -- Prediction ->Ankle boot against actual ->Ankle boot
# 681 -- Prediction ->Shirt against actual ->T-shirt/top
# 682 -- Prediction ->Bag against actual ->Bag
# 683 -- Prediction ->Ankle boot against actual ->Ankle boot
# 684 -- Prediction ->Shirt against actual ->Shirt
# 685 -- Prediction ->Dress against actual ->Coat
# 686 -- Prediction ->Pullover against actual ->Pullover
# 687 -- Prediction ->Ankle boot against actual ->Ankle boot
# 688 -- Prediction ->Shirt against actual ->Dress
# 689 -- Prediction ->Coat against actual ->Coat
# 690 -- Prediction ->Sandal against actual ->Sandal
# 691 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 692 -- Prediction ->Ankle boot against actual ->Ankle boot
# 693 -- Prediction ->Sandal against actual ->Sandal
# 694 -- Prediction ->Dress against actual ->Dress
# 695 -- Prediction ->Shirt against actual ->Shirt
# 696 -- Prediction ->Shirt against actual ->Shirt
# 697 -- Prediction ->Bag against actual ->Bag
# 698 -- Prediction ->Dress against actual ->Dress
# 699 -- Prediction ->Dress against actual ->Dress
# 700 -- Prediction ->Bag against actual ->Bag
# 701 -- Prediction ->Trouser against actual ->Trouser
# 702 -- Prediction ->Coat against actual ->Coat
# 703 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 704 -- Prediction ->Ankle boot against actual ->Ankle boot
# 705 -- Prediction ->Sneaker against actual ->Sneaker
# 706 -- Prediction ->Ankle boot against actual ->Ankle boot
# 707 -- Prediction ->Coat against actual ->Coat
# 708 -- Prediction ->Bag against actual ->Bag
# 709 -- Prediction ->Ankle boot against actual ->Ankle boot
# 710 -- Prediction ->Trouser against actual ->Trouser
# 711 -- Prediction ->Dress against actual ->Shirt
# 712 -- Prediction ->Sneaker against actual ->Sneaker
# 713 -- Prediction ->Dress against actual ->Dress
# 714 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 715 -- Prediction ->Pullover against actual ->Pullover
# 716 -- Prediction ->Shirt against actual ->Shirt
# 717 -- Prediction ->Sneaker against actual ->Sneaker
# 718 -- Prediction ->Trouser against actual ->Trouser
# 719 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 720 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 721 -- Prediction ->Bag against actual ->Bag
# 722 -- Prediction ->Sneaker against actual ->Sandal
# 723 -- Prediction ->Pullover against actual ->Pullover
# 724 -- Prediction ->Shirt against actual ->Shirt
# 725 -- Prediction ->Shirt against actual ->Shirt
# 726 -- Prediction ->Shirt against actual ->Shirt
# 727 -- Prediction ->Coat against actual ->Coat
# 728 -- Prediction ->Trouser against actual ->Trouser
# 729 -- Prediction ->Sandal against actual ->Sandal
# 730 -- Prediction ->Ankle boot against actual ->Ankle boot
# 731 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 732 -- Prediction ->T-shirt/top against actual ->Pullover
# 733 -- Prediction ->Trouser against actual ->Trouser
# 734 -- Prediction ->Shirt against actual ->Shirt
# 735 -- Prediction ->Sandal against actual ->Sandal
# 736 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 737 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 738 -- Prediction ->Dress against actual ->Dress
# 739 -- Prediction ->Dress against actual ->Dress
# 740 -- Prediction ->Dress against actual ->Dress
# 741 -- Prediction ->Bag against actual ->Bag
# 742 -- Prediction ->Trouser against actual ->Trouser
# 743 -- Prediction ->Trouser against actual ->Trouser
# 744 -- Prediction ->Bag against actual ->Bag
# 745 -- Prediction ->Sandal against actual ->Sandal
# 746 -- Prediction ->Sneaker against actual ->Sneaker
# 747 -- Prediction ->Sneaker against actual ->Sneaker
# 748 -- Prediction ->Bag against actual ->Bag
# 749 -- Prediction ->Sneaker against actual ->Sneaker
# 750 -- Prediction ->Pullover against actual ->Pullover
# 751 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 752 -- Prediction ->Sneaker against actual ->Sneaker
# 753 -- Prediction ->Dress against actual ->Dress
# 754 -- Prediction ->Bag against actual ->Bag
# 755 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 756 -- Prediction ->Ankle boot against actual ->Ankle boot
# 757 -- Prediction ->Sneaker against actual ->Sneaker
# 758 -- Prediction ->Shirt against actual ->Shirt
# 759 -- Prediction ->Trouser against actual ->Trouser
# 760 -- Prediction ->Shirt against actual ->Pullover
# 761 -- Prediction ->Pullover against actual ->Shirt
# 762 -- Prediction ->Coat against actual ->Coat
# 763 -- Prediction ->Bag against actual ->Bag
# 764 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 765 -- Prediction ->Shirt against actual ->Shirt
# 766 -- Prediction ->Dress against actual ->Dress
# 767 -- Prediction ->Shirt against actual ->Shirt
# 768 -- Prediction ->Bag against actual ->Bag
# 769 -- Prediction ->Coat against actual ->Coat
# 770 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 771 -- Prediction ->Bag against actual ->Bag
# 772 -- Prediction ->Ankle boot against actual ->Ankle boot
# 773 -- Prediction ->Pullover against actual ->Pullover
# 774 -- Prediction ->Coat against actual ->Coat
# 775 -- Prediction ->Sandal against actual ->Sandal
# 776 -- Prediction ->Ankle boot against actual ->Ankle boot
# 777 -- Prediction ->Trouser against actual ->Trouser
# 778 -- Prediction ->Coat against actual ->Coat
# 779 -- Prediction ->Coat against actual ->Coat
# 780 -- Prediction ->Ankle boot against actual ->Ankle boot
# 781 -- Prediction ->Pullover against actual ->Pullover
# 782 -- Prediction ->Trouser against actual ->Trouser
# 783 -- Prediction ->Sneaker against actual ->Sneaker
# 784 -- Prediction ->Ankle boot against actual ->Ankle boot
# 785 -- Prediction ->Sandal against actual ->Sandal
# 786 -- Prediction ->Bag against actual ->Bag
# 787 -- Prediction ->Dress against actual ->Trouser
# 788 -- Prediction ->Sneaker against actual ->Sneaker
# 789 -- Prediction ->Sneaker against actual ->Sneaker
# 790 -- Prediction ->Trouser against actual ->Trouser
# 791 -- Prediction ->Trouser against actual ->Trouser
# 792 -- Prediction ->Trouser against actual ->Trouser
# 793 -- Prediction ->Shirt against actual ->Shirt
# 794 -- Prediction ->Ankle boot against actual ->Ankle boot
# 795 -- Prediction ->Sandal against actual ->Sandal
# 796 -- Prediction ->Dress against actual ->Dress
# 797 -- Prediction ->Bag against actual ->Bag
# 798 -- Prediction ->Coat against actual ->Coat
# 799 -- Prediction ->Pullover against actual ->Pullover
# 800 -- Prediction ->Ankle boot against actual ->Sneaker
# 801 -- Prediction ->Pullover against actual ->Coat
# 802 -- Prediction ->Bag against actual ->Bag
# 803 -- Prediction ->Dress against actual ->Dress
# 804 -- Prediction ->Pullover against actual ->Pullover
# 805 -- Prediction ->Coat against actual ->Coat
# 806 -- Prediction ->Coat against actual ->Coat
# 807 -- Prediction ->Sneaker against actual ->Sneaker
# 808 -- Prediction ->Trouser against actual ->Trouser
# 809 -- Prediction ->Dress against actual ->Coat
# 810 -- Prediction ->Ankle boot against actual ->Ankle boot
# 811 -- Prediction ->Dress against actual ->Dress
# 812 -- Prediction ->Sandal against actual ->Sandal
# 813 -- Prediction ->Bag against actual ->Bag
# 814 -- Prediction ->Sandal against actual ->Sandal
# 815 -- Prediction ->Coat against actual ->Coat
# 816 -- Prediction ->Sneaker against actual ->Sneaker
# 817 -- Prediction ->Pullover against actual ->Pullover
# 818 -- Prediction ->Bag against actual ->Bag
# 819 -- Prediction ->Sandal against actual ->Sandal
# 820 -- Prediction ->Ankle boot against actual ->Ankle boot
# 821 -- Prediction ->Dress against actual ->Dress
# 822 -- Prediction ->Dress against actual ->Dress
# 823 -- Prediction ->Shirt against actual ->Shirt
# 824 -- Prediction ->Sneaker against actual ->Sneaker
# 825 -- Prediction ->Trouser against actual ->Trouser
# 826 -- Prediction ->Sneaker against actual ->Sneaker
# 827 -- Prediction ->Dress against actual ->Dress
# 828 -- Prediction ->Sandal against actual ->Sandal
# 829 -- Prediction ->Coat against actual ->Coat
# 830 -- Prediction ->Shirt against actual ->Coat
# 831 -- Prediction ->Sandal against actual ->Sandal
# 832 -- Prediction ->Bag against actual ->Bag
# 833 -- Prediction ->Dress against actual ->Dress
# 834 -- Prediction ->Sneaker against actual ->Sneaker
# 835 -- Prediction ->Trouser against actual ->Trouser
# 836 -- Prediction ->Pullover against actual ->Pullover
# 837 -- Prediction ->Shirt against actual ->Shirt
# 838 -- Prediction ->Trouser against actual ->Trouser
# 839 -- Prediction ->Ankle boot against actual ->Ankle boot
# 840 -- Prediction ->Bag against actual ->Bag
# 841 -- Prediction ->Pullover against actual ->Pullover
# 842 -- Prediction ->Sneaker against actual ->Sneaker
# 843 -- Prediction ->Trouser against actual ->Trouser
# 844 -- Prediction ->Dress against actual ->Dress
# 845 -- Prediction ->Sneaker against actual ->Sneaker
# 846 -- Prediction ->Sandal against actual ->Sandal
# 847 -- Prediction ->Ankle boot against actual ->Ankle boot
# 848 -- Prediction ->Ankle boot against actual ->Ankle boot
# 849 -- Prediction ->Trouser against actual ->Trouser
# 850 -- Prediction ->Bag against actual ->Bag
# 851 -- Prediction ->Coat against actual ->Pullover
# 852 -- Prediction ->Sneaker against actual ->Sandal
# 853 -- Prediction ->Sneaker against actual ->Sneaker
# 854 -- Prediction ->Trouser against actual ->Trouser
# 855 -- Prediction ->Ankle boot against actual ->Ankle boot
# 856 -- Prediction ->Bag against actual ->Bag
# 857 -- Prediction ->Trouser against actual ->Trouser
# 858 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 859 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 860 -- Prediction ->Dress against actual ->Shirt
# 861 -- Prediction ->Trouser against actual ->Trouser
# 862 -- Prediction ->Sneaker against actual ->Sneaker
# 863 -- Prediction ->Trouser against actual ->Trouser
# 864 -- Prediction ->Trouser against actual ->Trouser
# 865 -- Prediction ->Sandal against actual ->Sandal
# 866 -- Prediction ->Sneaker against actual ->Sneaker
# 867 -- Prediction ->Trouser against actual ->Trouser
# 868 -- Prediction ->Sandal against actual ->Sandal
# 869 -- Prediction ->Pullover against actual ->Pullover
# 870 -- Prediction ->Pullover against actual ->Pullover
# 871 -- Prediction ->Dress against actual ->Dress
# 872 -- Prediction ->Dress against actual ->Dress
# 873 -- Prediction ->Trouser against actual ->Trouser
# 874 -- Prediction ->Trouser against actual ->Trouser
# 875 -- Prediction ->Coat against actual ->Coat
# 876 -- Prediction ->Ankle boot against actual ->Ankle boot
# 877 -- Prediction ->Coat against actual ->Coat
# 878 -- Prediction ->Dress against actual ->Dress
# 879 -- Prediction ->Sneaker against actual ->Sneaker
# 880 -- Prediction ->Sneaker against actual ->Sneaker
# 881 -- Prediction ->Shirt against actual ->T-shirt/top
# 882 -- Prediction ->Bag against actual ->Bag
# 883 -- Prediction ->Ankle boot against actual ->Ankle boot
# 884 -- Prediction ->Ankle boot against actual ->Ankle boot
# 885 -- Prediction ->Shirt against actual ->Shirt
# 886 -- Prediction ->Trouser against actual ->Trouser
# 887 -- Prediction ->Dress against actual ->Dress
# 888 -- Prediction ->Coat against actual ->Coat
# 889 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 890 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 891 -- Prediction ->Sandal against actual ->Sandal
# 892 -- Prediction ->Ankle boot against actual ->Ankle boot
# 893 -- Prediction ->Coat against actual ->Pullover
# 894 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 895 -- Prediction ->Sandal against actual ->Sandal
# 896 -- Prediction ->Sandal against actual ->Sandal
# 897 -- Prediction ->Trouser against actual ->Trouser
# 898 -- Prediction ->Sandal against actual ->Sandal
# 899 -- Prediction ->Sneaker against actual ->Sneaker
# 900 -- Prediction ->Bag against actual ->Bag
# 901 -- Prediction ->Sneaker against actual ->Sneaker
# 902 -- Prediction ->Sneaker against actual ->Sandal
# 903 -- Prediction ->Dress against actual ->Dress
# 904 -- Prediction ->Shirt against actual ->Shirt
# 905 -- Prediction ->Shirt against actual ->Coat
# 906 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 907 -- Prediction ->Coat against actual ->Coat
# 908 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 909 -- Prediction ->Pullover against actual ->Shirt
# 910 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 911 -- Prediction ->Pullover against actual ->Pullover
# 912 -- Prediction ->Sandal against actual ->Sandal
# 913 -- Prediction ->Sandal against actual ->Sandal
# 914 -- Prediction ->Trouser against actual ->Trouser
# 915 -- Prediction ->Pullover against actual ->Pullover
# 916 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 917 -- Prediction ->Ankle boot against actual ->Ankle boot
# 918 -- Prediction ->Dress against actual ->Dress
# 919 -- Prediction ->Sneaker against actual ->Sneaker
# ...
# 9699 -- Prediction ->Coat against actual ->Coat
# 9700 -- Prediction ->Dress against actual ->Dress
# 9701 -- Prediction ->Shirt against actual ->Coat
# 9702 -- Prediction ->Coat against actual ->Coat
# 9703 -- Prediction ->Sandal against actual ->Sandal
# 9704 -- Prediction ->Sneaker against actual ->Sneaker
# 9705 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9706 -- Prediction ->Coat against actual ->Pullover
# 9707 -- Prediction ->Sandal against actual ->Sandal
# 9708 -- Prediction ->Pullover against actual ->Pullover
# 9709 -- Prediction ->Coat against actual ->Coat
# 9710 -- Prediction ->Sandal against actual ->Sandal
# 9711 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9712 -- Prediction ->Trouser against actual ->Trouser
# 9713 -- Prediction ->Sneaker against actual ->Sneaker
# 9714 -- Prediction ->Shirt against actual ->Shirt
# 9715 -- Prediction ->Sneaker against actual ->Sneaker
# 9716 -- Prediction ->Shirt against actual ->Shirt
# 9717 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9718 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9719 -- Prediction ->Shirt against actual ->T-shirt/top
# 9720 -- Prediction ->Sandal against actual ->Sandal
# 9721 -- Prediction ->Trouser against actual ->Trouser
# 9722 -- Prediction ->Trouser against actual ->Trouser
# 9723 -- Prediction ->Pullover against actual ->Pullover
# 9724 -- Prediction ->Dress against actual ->Coat
# 9725 -- Prediction ->Shirt against actual ->Shirt
# 9726 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9727 -- Prediction ->Bag against actual ->Bag
# 9728 -- Prediction ->Trouser against actual ->Trouser
# 9729 -- Prediction ->T-shirt/top against actual ->Shirt
# 9730 -- Prediction ->Trouser against actual ->Trouser
# 9731 -- Prediction ->Shirt against actual ->Shirt
# 9732 -- Prediction ->Bag against actual ->Bag
# 9733 -- Prediction ->Sandal against actual ->Sandal
# 9734 -- Prediction ->Coat against actual ->Coat
# 9735 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9736 -- Prediction ->Coat against actual ->Coat
# 9737 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9738 -- Prediction ->Coat against actual ->Coat
# 9739 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9740 -- Prediction ->Dress against actual ->Dress
# 9741 -- Prediction ->Bag against actual ->Bag
# 9742 -- Prediction ->Sandal against actual ->Sandal
# 9743 -- Prediction ->Coat against actual ->Pullover
# 9744 -- Prediction ->Bag against actual ->Bag
# 9745 -- Prediction ->Shirt against actual ->Shirt
# 9746 -- Prediction ->Pullover against actual ->Pullover
# 9747 -- Prediction ->Bag against actual ->Bag
# 9748 -- Prediction ->Shirt against actual ->T-shirt/top
# 9749 -- Prediction ->Coat against actual ->Coat
# 9750 -- Prediction ->Coat against actual ->Coat
# 9751 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9752 -- Prediction ->Bag against actual ->Bag
# 9753 -- Prediction ->Sneaker against actual ->Sneaker
# 9754 -- Prediction ->Sandal against actual ->Sandal
# 9755 -- Prediction ->Pullover against actual ->Pullover
# 9756 -- Prediction ->Bag against actual ->Bag
# 9757 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9758 -- Prediction ->Pullover against actual ->Pullover
# 9759 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9760 -- Prediction ->Sandal against actual ->Sandal
# 9761 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9762 -- Prediction ->Pullover against actual ->Pullover
# 9763 -- Prediction ->Trouser against actual ->Trouser
# 9764 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9765 -- Prediction ->Coat against actual ->Coat
# 9766 -- Prediction ->Trouser against actual ->Trouser
# 9767 -- Prediction ->Sneaker against actual ->Sneaker
# 9768 -- Prediction ->Sneaker against actual ->Sneaker
# 9769 -- Prediction ->Trouser against actual ->Trouser
# 9770 -- Prediction ->Sneaker against actual ->Sneaker
# 9771 -- Prediction ->Dress against actual ->Dress
# 9772 -- Prediction ->Sandal against actual ->Sandal
# 9773 -- Prediction ->Bag against actual ->Bag
# 9774 -- Prediction ->Sneaker against actual ->Sneaker
# 9775 -- Prediction ->Pullover against actual ->Pullover
# 9776 -- Prediction ->Sandal against actual ->Sandal
# 9777 -- Prediction ->Trouser against actual ->Trouser
# 9778 -- Prediction ->Sandal against actual ->Sandal
# 9779 -- Prediction ->Shirt against actual ->Pullover
# 9780 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9781 -- Prediction ->Shirt against actual ->Shirt
# 9782 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9783 -- Prediction ->Trouser against actual ->Trouser
# 9784 -- Prediction ->Coat against actual ->Pullover
# 9785 -- Prediction ->Coat against actual ->Coat
# 9786 -- Prediction ->Coat against actual ->Coat
# 9787 -- Prediction ->Bag against actual ->Bag
# 9788 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9789 -- Prediction ->Dress against actual ->Dress
# 9790 -- Prediction ->Pullover against actual ->Pullover
# 9791 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9792 -- Prediction ->Dress against actual ->Dress
# 9793 -- Prediction ->Sandal against actual ->Sandal
# 9794 -- Prediction ->Trouser against actual ->Trouser
# 9795 -- Prediction ->Dress against actual ->Dress
# 9796 -- Prediction ->Dress against actual ->Dress
# 9797 -- Prediction ->Shirt against actual ->T-shirt/top
# 9798 -- Prediction ->Sandal against actual ->Sandal
# 9799 -- Prediction ->Trouser against actual ->Trouser
# 9800 -- Prediction ->Bag against actual ->Bag
# 9801 -- Prediction ->Dress against actual ->Dress
# 9802 -- Prediction ->Trouser against actual ->Trouser
# 9803 -- Prediction ->Bag against actual ->Bag
# 9804 -- Prediction ->Sneaker against actual ->Sneaker
# 9805 -- Prediction ->Bag against actual ->Bag
# 9806 -- Prediction ->Coat against actual ->Coat
# 9807 -- Prediction ->Coat against actual ->Pullover
# 9808 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9809 -- Prediction ->Dress against actual ->T-shirt/top
# 9810 -- Prediction ->Sneaker against actual ->Sneaker
# 9811 -- Prediction ->Bag against actual ->Bag
# 9812 -- Prediction ->Trouser against actual ->Trouser
# 9813 -- Prediction ->Dress against actual ->Dress
# 9814 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9815 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9816 -- Prediction ->Pullover against actual ->Pullover
# 9817 -- Prediction ->Bag against actual ->Bag
# 9818 -- Prediction ->Trouser against actual ->Trouser
# 9819 -- Prediction ->Coat against actual ->Coat
# 9820 -- Prediction ->Bag against actual ->Bag
# 9821 -- Prediction ->Bag against actual ->Bag
# 9822 -- Prediction ->Dress against actual ->Dress
# 9823 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9824 -- Prediction ->Bag against actual ->Bag
# 9825 -- Prediction ->Sandal against actual ->Sandal
# 9826 -- Prediction ->Sneaker against actual ->Sneaker
# 9827 -- Prediction ->Sandal against actual ->Sandal
# 9828 -- Prediction ->Coat against actual ->Coat
# 9829 -- Prediction ->Sneaker against actual ->Sneaker
# 9830 -- Prediction ->Sneaker against actual ->Sneaker
# 9831 -- Prediction ->Shirt against actual ->Shirt
# 9832 -- Prediction ->Trouser against actual ->Trouser
# 9833 -- Prediction ->Bag against actual ->Bag
# 9834 -- Prediction ->Trouser against actual ->Trouser
# 9835 -- Prediction ->Sneaker against actual ->Ankle boot
# 9836 -- Prediction ->Sneaker against actual ->Sneaker
# 9837 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9838 -- Prediction ->Dress against actual ->Dress
# 9839 -- Prediction ->Trouser against actual ->Trouser
# 9840 -- Prediction ->Shirt against actual ->Shirt
# 9841 -- Prediction ->Sandal against actual ->Sandal
# 9842 -- Prediction ->Sandal against actual ->Sandal
# 9843 -- Prediction ->Dress against actual ->Dress
# 9844 -- Prediction ->Bag against actual ->Bag
# 9845 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9846 -- Prediction ->Dress against actual ->Coat
# 9847 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9848 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9849 -- Prediction ->Sandal against actual ->Sandal
# 9850 -- Prediction ->Trouser against actual ->Trouser
# 9851 -- Prediction ->Sneaker against actual ->Sneaker
# 9852 -- Prediction ->Shirt against actual ->Pullover
# 9853 -- Prediction ->Trouser against actual ->Trouser
# 9854 -- Prediction ->Sandal against actual ->Sandal
# 9855 -- Prediction ->Pullover against actual ->Pullover
# 9856 -- Prediction ->Bag against actual ->Bag
# 9857 -- Prediction ->Dress against actual ->Dress
# 9858 -- Prediction ->Dress against actual ->Dress
# 9859 -- Prediction ->Dress against actual ->Shirt
# 9860 -- Prediction ->Sneaker against actual ->Sneaker
# 9861 -- Prediction ->Trouser against actual ->Trouser
# 9862 -- Prediction ->Dress against actual ->Dress
# 9863 -- Prediction ->Coat against actual ->Coat
# 9864 -- Prediction ->Coat against actual ->Coat
# 9865 -- Prediction ->Sneaker against actual ->Sandal
# 9866 -- Prediction ->Sneaker against actual ->Sneaker
# 9867 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9868 -- Prediction ->Shirt against actual ->Shirt
# 9869 -- Prediction ->Sneaker against actual ->Sneaker
# 9870 -- Prediction ->Dress against actual ->Dress
# 9871 -- Prediction ->Dress against actual ->Dress
# 9872 -- Prediction ->Sneaker against actual ->Sneaker
# 9873 -- Prediction ->Bag against actual ->Bag
# 9874 -- Prediction ->Bag against actual ->Bag
# 9875 -- Prediction ->Pullover against actual ->Pullover
# 9876 -- Prediction ->Ankle boot against actual ->Sandal
# 9877 -- Prediction ->Shirt against actual ->Shirt
# 9878 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9879 -- Prediction ->Sneaker against actual ->Sneaker
# 9880 -- Prediction ->Dress against actual ->T-shirt/top
# 9881 -- Prediction ->Pullover against actual ->Pullover
# 9882 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9883 -- Prediction ->Dress against actual ->Dress
# 9884 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9885 -- Prediction ->Sandal against actual ->Sandal
# 9886 -- Prediction ->Sandal against actual ->Sandal
# 9887 -- Prediction ->Shirt against actual ->Shirt
# 9888 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9889 -- Prediction ->Trouser against actual ->Trouser
# 9890 -- Prediction ->Coat against actual ->Coat
# 9891 -- Prediction ->Trouser against actual ->Trouser
# 9892 -- Prediction ->Sandal against actual ->Sandal
# 9893 -- Prediction ->Shirt against actual ->Shirt
# 9894 -- Prediction ->Coat against actual ->Coat
# 9895 -- Prediction ->Trouser against actual ->Trouser
# 9896 -- Prediction ->Coat against actual ->Coat
# 9897 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9898 -- Prediction ->Dress against actual ->Dress
# 9899 -- Prediction ->Dress against actual ->Dress
# 9900 -- Prediction ->Shirt against actual ->Shirt
# 9901 -- Prediction ->Dress against actual ->Dress
# 9902 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9903 -- Prediction ->Bag against actual ->Bag
# 9904 -- Prediction ->Coat against actual ->Shirt
# 9905 -- Prediction ->Sneaker against actual ->Sneaker
# 9906 -- Prediction ->Sandal against actual ->Sandal
# 9907 -- Prediction ->Sandal against actual ->Sandal
# 9908 -- Prediction ->Sneaker against actual ->Sneaker
# 9909 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9910 -- Prediction ->Sneaker against actual ->Sneaker
# 9911 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9912 -- Prediction ->Coat against actual ->Coat
# 9913 -- Prediction ->Dress against actual ->Coat
# 9914 -- Prediction ->Pullover against actual ->Pullover
# 9915 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9916 -- Prediction ->Trouser against actual ->Trouser
# 9917 -- Prediction ->Ankle boot against actual ->Sneaker
# 9918 -- Prediction ->Trouser against actual ->Trouser
# 9919 -- Prediction ->Bag against actual ->Bag
# 9920 -- Prediction ->Bag against actual ->Bag
# 9921 -- Prediction ->Bag against actual ->Bag
# 9922 -- Prediction ->Sandal against actual ->Sandal
# 9923 -- Prediction ->Bag against actual ->Bag
# 9924 -- Prediction ->Dress against actual ->Dress
# 9925 -- Prediction ->Bag against actual ->Bag
# 9926 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9927 -- Prediction ->Dress against actual ->Dress
# 9928 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9929 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9930 -- Prediction ->Shirt against actual ->Pullover
# 9931 -- Prediction ->Trouser against actual ->Trouser
# 9932 -- Prediction ->Bag against actual ->Bag
# 9933 -- Prediction ->Coat against actual ->Coat
# 9934 -- Prediction ->Shirt against actual ->Coat
# 9935 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9936 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9937 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9938 -- Prediction ->Sandal against actual ->Sandal
# 9939 -- Prediction ->Dress against actual ->Dress
# 9940 -- Prediction ->Trouser against actual ->Trouser
# 9941 -- Prediction ->Ankle boot against actual ->Sandal
# 9942 -- Prediction ->Trouser against actual ->Trouser
# 9943 -- Prediction ->Dress against actual ->Dress
# 9944 -- Prediction ->Sandal against actual ->Sandal
# 9945 -- Prediction ->Dress against actual ->T-shirt/top
# 9946 -- Prediction ->Shirt against actual ->Pullover
# 9947 -- Prediction ->Pullover against actual ->Shirt
# 9948 -- Prediction ->Trouser against actual ->Trouser
# 9949 -- Prediction ->Sneaker against actual ->Sandal
# 9950 -- Prediction ->Dress against actual ->Dress
# 9951 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9952 -- Prediction ->Bag against actual ->Bag
# 9953 -- Prediction ->Pullover against actual ->Shirt
# 9954 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9955 -- Prediction ->Shirt against actual ->Shirt
# 9956 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9957 -- Prediction ->Shirt against actual ->Shirt
# 9958 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9959 -- Prediction ->Coat against actual ->Coat
# 9960 -- Prediction ->Trouser against actual ->Trouser
# 9961 -- Prediction ->Pullover against actual ->Shirt
# 9962 -- Prediction ->Shirt against actual ->Shirt
# 9963 -- Prediction ->Coat against actual ->Coat
# 9964 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9965 -- Prediction ->Trouser against actual ->Trouser
# 9966 -- Prediction ->Coat against actual ->Coat
# 9967 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9968 -- Prediction ->Sneaker against actual ->Sneaker
# 9969 -- Prediction ->Bag against actual ->Bag
# 9970 -- Prediction ->Pullover against actual ->Pullover
# 9971 -- Prediction ->Shirt against actual ->Shirt
# 9972 -- Prediction ->T-shirt/top against actual ->Pullover
# 9973 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9974 -- Prediction ->Sneaker against actual ->Sneaker
# 9975 -- Prediction ->Bag against actual ->Bag
# 9976 -- Prediction ->Sandal against actual ->Sandal
# 9977 -- Prediction ->T-shirt/top against actual ->Shirt
# 9978 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9979 -- Prediction ->Shirt against actual ->Shirt
# 9980 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9981 -- Prediction ->T-shirt/top against actual ->T-shirt/top
# 9982 -- Prediction ->Bag against actual ->Bag
# 9983 -- Prediction ->Trouser against actual ->Trouser
# 9984 -- Prediction ->Dress against actual ->Dress
# 9985 -- Prediction ->T-shirt/top against actual ->Pullover
# 9986 -- Prediction ->Sneaker against actual ->Sneaker
# 9987 -- Prediction ->Sandal against actual ->Sandal
# 9988 -- Prediction ->Bag against actual ->Bag
# 9989 -- Prediction ->Pullover against actual ->Coat
# 9990 -- Prediction ->Sandal against actual ->Sandal
# 9991 -- Prediction ->Shirt against actual ->Shirt
# 9992 -- Prediction ->Bag against actual ->Bag
# 9993 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9994 -- Prediction ->Trouser against actual ->Trouser
# 9995 -- Prediction ->Ankle boot against actual ->Ankle boot
# 9996 -- Prediction ->Trouser against actual ->Trouser
# 9997 -- Prediction ->Bag against actual ->Bag
# 9998 -- Prediction ->Trouser against actual ->Trouser
# 9999 -- Prediction ->Sandal against actual ->Sandal
