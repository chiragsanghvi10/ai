# %%
#https://github.com/SEERNET/deepaffects-python/issues/35

# %%
from deepaffects.realtime.util import chunk_generator_from_file, chunk_generator_from_url, get_deepaffects_client

# %%
TIMEOUT_SECONDS = 2000

# %%
apikey = "UPaRHLWDeTdDMJYA3Dt4MlApTGYqCnyw"

# %%
# Set file_path as local file path or audio stream or youtube url
file_path = "/home/absin/Downloads/17913385.wav"

# %%
# Set is_youtube_url True while streaming from youtube url
is_youtube_url = False
languageCode = "en-IN"
sampleRate = "44100"
encoding = "wav"

# %%
# DeepAffects realtime Api client
client = get_deepaffects_client()

# %%
metadata = [
    ('apikey', apikey),
    ('encoding', encoding),
    ('samplerate', sampleRate),
    ('languagecode', languageCode)
]

# %%
responses = client.IdentifyEmotion(
    # Use chunk_generator_from_file generator to stream from local file
    chunk_generator_from_file(file_path),
    # Use chunk_generator_from_url generator to stream from remote url or youtube with is_youtube_url set to true
    # chunk_generator_from_url(file_path, is_youtube_url=is_youtube_url),
     TIMEOUT_SECONDS, metadata=metadata)

# responses is the iterator for all the response values
for response in responses:
    print("Received message",response)
# Out:
# Sending chunk 0 - with size :- 30.0 sec
# Sending chunk 1 - with size :- 30.0 sec
# Sending chunk 2 - with size :- 30.0 sec
# Sending chunk 3 - with size :- 30.0 sec
# Sending chunk 4 - with size :- 30.0 sec
# Sending chunk 5 - with size :- 30.0 sec
# Sending chunk 6 - with size :- 30.0 sec
# Received message end: 15.0
# emotion: "neutral"
#
# Received message start: 15.0
# end: 18.0
# emotion: "sad"
#
# Received message start: 18.0
# end: 21.0
# emotion: "excited"
#
# Received message start: 21.0
# end: 24.0
# emotion: "neutral"
#
# Received message start: 24.0
# end: 27.0
# emotion: "excited"
#
# Received message start: 27.0
# end: 30.0
# emotion: "neutral"
#
# Sending chunk 7 - with size :- 30.0 sec
# Sending chunk 8 - with size :- 30.0 sec
# Sending chunk 9 - with size :- 30.0 sec
# Sending chunk 10 - with size :- 30.0 sec
# Received message start: 30.0
# end: 33.0
# emotion: "anger"
#
# Received message start: 33.0
# end: 39.0
# emotion: "neutral"
#
# Received message start: 39.0
# end: 42.0
# emotion: "excited"
#
# Received message start: 42.0
# end: 45.0
# emotion: "neutral"
#
# Received message start: 45.0
# end: 48.0
# emotion: "excited"
#
# Received message start: 48.0
# end: 51.0
# emotion: "happy"
#
# Received message start: 51.0
# end: 54.0
# emotion: "neutral"
#
# Received message start: 54.0
# end: 60.0
# emotion: "excited"
#
# Received message start: 60.0
# end: 63.0
# emotion: "neutral"
#
# Received message start: 63.0
# end: 66.0
# emotion: "excited"
#
# Received message start: 66.0
# end: 84.0
# emotion: "neutral"
#
# Received message start: 84.0
# end: 87.0
# emotion: "anger"
#
# Received message start: 87.0
# end: 90.0
# emotion: "frustration"
#
# Received message start: 90.0
# end: 93.0
# emotion: "excited"
#
# Received message start: 93.0
# end: 102.0
# emotion: "neutral"
#
# Received message start: 102.0
# end: 105.0
# emotion: "excited"
#
# Received message start: 105.0
# end: 108.0
# emotion: "frustration"
#
# Received message start: 108.0
# end: 111.0
# emotion: "neutral"
#
# Received message start: 111.0
# end: 117.0
# emotion: "excited"
#
# Received message start: 117.0
# end: 120.0
# emotion: "happy"
#
# Received message start: 120.0
# end: 123.0
# emotion: "excited"
#
# Received message start: 123.0
# end: 129.0
# emotion: "neutral"
#
# Received message start: 129.0
# end: 132.0
# emotion: "anger"
#
# Received message start: 132.0
# end: 135.0
# emotion: "neutral"
#
# Received message start: 135.0
# end: 138.0
# emotion: "excited"
#
# Received message start: 138.0
# end: 144.0
# emotion: "neutral"
#
# Received message start: 144.0
# end: 147.0
# emotion: "excited"
#
# Received message start: 147.0
# end: 150.0
# emotion: "neutral"
#
# Received message start: 150.0
# end: 153.0
# emotion: "neutral"
#
# Received message start: 153.0
# end: 156.0
# emotion: "anger"
#
# Received message start: 156.0
# end: 159.0
# emotion: "neutral"
#
# Received message start: 159.0
# end: 162.0
# emotion: "excited"
#
# Received message start: 162.0
# end: 165.0
# emotion: "anger"
#
# Received message start: 165.0
# end: 168.0
# emotion: "neutral"
#
# Received message start: 168.0
# end: 171.0
# emotion: "excited"
#
# Received message start: 171.0
# end: 177.0
# emotion: "neutral"
#
# Received message start: 177.0
# end: 180.0
# emotion: "excited"
#
# Sending chunk 11 - with size :- 30.0 sec
# Sending chunk 12 - with size :- 30.0 sec
# Sending chunk 13 - with size :- 30.0 sec
# Received message start: 180.0
# end: 189.0
# emotion: "excited"
#
# Received message start: 189.0
# end: 192.0
# emotion: "neutral"
#
# Received message start: 192.0
# end: 195.0
# emotion: "excited"
#
# Received message start: 195.0
# end: 198.0
# emotion: "neutral"
#
# Received message start: 198.0
# end: 201.0
# emotion: "excited"
#
# Received message start: 201.0
# end: 204.0
# emotion: "neutral"
#
# Received message start: 204.0
# end: 207.0
# emotion: "frustration"
#
# Received message start: 207.0
# end: 210.0
# emotion: "anger"
#
# Sending chunk 14 - with size :- 30.0 sec
# Received message start: 210.0
# end: 225.0
# emotion: "neutral"
#
# Received message start: 225.0
# end: 228.0
# emotion: "frustration"
#
# Received message start: 228.0
# end: 231.0
# emotion: "neutral"
#
# Received message start: 231.0
# end: 234.0
# emotion: "happy"
#
# Received message start: 234.0
# end: 237.0
# emotion: "neutral"
#
# Received message start: 237.0
# end: 240.0
# emotion: "sad"
#
# Received message start: 240.0
# end: 246.0
# emotion: "neutral"
#
# Received message start: 246.0
# end: 249.0
# emotion: "frustration"
#
# Received message start: 249.0
# end: 258.0
# emotion: "neutral"
#
# Received message start: 258.0
# end: 261.0
# emotion: "frustration"
#
# Received message start: 261.0
# end: 264.0
# emotion: "excited"
#
# Received message start: 264.0
# end: 270.0
# emotion: "neutral"
#
# Received message start: 270.0
# end: 288.0
# emotion: "neutral"
#
# Received message start: 288.0
# end: 291.0
# emotion: "frustration"
#
# Received message start: 291.0
# end: 300.0
# emotion: "neutral"
#
# Sending chunk 15 - with size :- 30.0 sec
# Sending chunk 16 - with size :- 30.0 sec
# Sending chunk 17 - with size :- 30.0 sec
# Sending chunk 18 - with size :- 16.056 sec
# Received message start: 300.0
# end: 318.0
# emotion: "neutral"
#
# Received message start: 318.0
# end: 321.0
# emotion: "excited"
#
# Received message start: 321.0
# end: 327.0
# emotion: "neutral"
#
# Received message start: 327.0
# end: 330.0
# emotion: "frustration"
#
# Received message start: 330.0
# end: 336.0
# emotion: "excited"
#
# Received message start: 336.0
# end: 351.0
# emotion: "neutral"
#
# Received message start: 351.0
# end: 354.0
# emotion: "happy"
#
# Received message start: 354.0
# end: 360.0
# emotion: "neutral"
#
# Received message start: 360.0
# end: 363.0
# emotion: "excited"
#
# Received message start: 363.0
# end: 372.0
# emotion: "neutral"
#
# Received message start: 372.0
# end: 375.0
# emotion: "frustration"
#
# Received message start: 375.0
# end: 378.0
# emotion: "neutral"
#
# Received message start: 378.0
# end: 381.0
# emotion: "anger"
#
# Received message start: 381.0
# end: 387.0
# emotion: "neutral"
#
# Received message start: 387.0
# end: 390.0
# emotion: "excited"
#
# Received message start: 390.0
# end: 393.0
# emotion: "excited"
#
# Received message start: 393.0
# end: 402.0
# emotion: "neutral"
#
# Received message start: 402.0
# end: 405.0
# emotion: "excited"
#
# Received message start: 405.0
# end: 411.0
# emotion: "neutral"
#
# Received message start: 411.0
# end: 414.0
# emotion: "frustration"
#
# Received message start: 414.0
# end: 420.0
# emotion: "neutral"
#
# Received message start: 420.0
# end: 429.0
# emotion: "neutral"
#
# Received message start: 429.0
# end: 432.0
# emotion: "frustration"
#
# Received message start: 432.0
# end: 450.0
# emotion: "neutral"
#
# Received message start: 450.0
# end: 459.0
# emotion: "neutral"
#
# Received message start: 459.0
# end: 462.0
# emotion: "excited"
#
# Received message start: 462.0
# end: 468.0
# emotion: "neutral"
#
# Received message start: 468.0
# end: 471.0
# emotion: "frustration"
#
# Received message start: 471.0
# end: 474.0
# emotion: "neutral"
#
# Received message start: 474.0
# end: 480.0
# emotion: "excited"
#
# Received message start: 480.0
# end: 483.0
# emotion: "neutral"
#
# Received message start: 483.0
# end: 486.0
# emotion: "excited"
#
# Received message start: 486.0
# end: 489.0
# emotion: "happy"
#
# Received message start: 489.0
# end: 495.0
# emotion: "excited"
#
# Received message start: 495.0
# end: 498.0
# emotion: "happy"
#
# Received message start: 498.0
# end: 501.0
# emotion: "anger"
#
# Received message start: 501.0
# end: 504.0
# emotion: "excited"
#
# Received message start: 504.0
# end: 507.0
# emotion: "frustration"
#
# Received message start: 507.0
# end: 510.0
# emotion: "neutral"
#
# Received message start: 510.0
# end: 513.0
# emotion: "excited"
#
# Received message start: 513.0
# end: 516.0
# emotion: "neutral"
#
# Received message start: 516.0
# end: 519.0
# emotion: "excited"
#
# Received message start: 519.0
# end: 528.0
# emotion: "neutral"
#
# Received message start: 528.0
# end: 531.0
# emotion: "excited"
#
# Received message start: 531.0
# end: 534.0
# emotion: "neutral"
#
# Received message start: 534.0
# end: 537.0
# emotion: "frustration"
#
# Received message start: 537.0
# end: 540.0
# emotion: "neutral"
#
# Received message start: 540.0
# end: 543.0
# emotion: "neutral"
#
# Received message start: 543.0
# end: 546.0
# emotion: "happy"
#
# Received message start: 546.0
# end: 556.1
# emotion: "neutral"
